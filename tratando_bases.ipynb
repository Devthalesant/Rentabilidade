# %% [markdown]
# ##  Bibliotecas e Dicionários

# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd
import numpy as np
import os
import glob
from pathlib import Path

# %% [markdown]
# ### Dicionários

# %%
Appointments_dic = {
    "RADIOFREQUÊNCIA CORPORAL SESSÃO": "RADIOFREQUÊNCIA",
    "LIMPEZA DE PELE SESSÃO": "LIMPEZA DE PELE",
    "HECCUS / MANTHUS SESSÃO": "HECCUS",
    "DRENAGEM LINFÁTICA SESSÃO": "DRENAGEM",
    "BOTOX LIGHT (25 Unidades)": "BOTOX LIGHT",
    "BOTOX POWER (50 Unidades)": "BOTOX POWER",
    "PRÓ-SHAPE SESSÃO": "PRÓ-SHAPE",
    "PEELING QUÍMICO SESSÃO": "PEELING QUÍMICO",
    "DERMAROLLER ROSTO (Sessão)": "DERMAROLLER",
    "SECAGEM DE VASINHOS (SESSÃO) (EXCLUSIVO PARA AGENDAMENTO)": "SECAGEM",
    "RADIOFREQUÊNCIA SESSÃO CORTESIA": "RADIOFREQUÊNCIA",
    "CARBOXITERAPIA FACIAL SESSÃO": "CARBOXITERAPIA",
    "CARBOXITERAPIA CORPORAL SESSÃO": "CARBOXITERAPIA",
    "LIMPEZA DE PELE SESSÃO EXCLUSIVO R$ 50 (EXCLUSIVO PARA AGENDAMENTO)": "LIMPEZA DE PELE",
    "SCULPTRA 1 FRASCO": "SCULPTRA",
    "ENZIMAS PRÓ-MESO SESSÃO": "PRÓ-MESO",
    "MASSAGEM PRÓ-DETOX SESSÃO": "DRENAGEM",
    "RADIOFREQUÊNCIA FACIAL SESSÃO": "RADIOFREQUÊNCIA",
    "CO2 ROSTO (Sessão)": "CO2 ROSTO",
    "ENZIMAS PRÓ-FIT SESSÃO": "PRÓ-FIT",
    "PREENCHIMENTO 1ML": "PREENCHIMENTO",
    "HIDRATAÇÃO FACIAL RUBY SESSÃO": "HIDRATAÇÃO",
    "ENZIMAS PRÓ-LIPO SESSÃO": "PRÓ-LIPO",
    "PEELING DE DIAMANTE SESSÃO": "PEELING DE DIAMANTE",
    "MASSAGEM PRÓ-DETOX SESSÃO CORTESIA": "DRENAGEM",
    "ENZIMAS PRÓ-FIRM SESSÃO": "PRÓ-FIRM",
    "PEELING DE DIAMANTE SESSÃO CORTESIA": "PEELING DE DIAMANTE",
    "CO2 COLO (Sessão)": "CO2 COLO",
    "RETOQUE TOXINA BOTULÍNICA": "RETOQUE",
    "LIMPEZA DE PELE SESSÃO CORTESIA": "LIMPEZA DE PELE",
    "DRENAGEM FACIAL SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "DRENAGEM",
    "HIDRATAÇÃO FACIAL PINK DIAMOND SESSÃO CORTESIA": "HIDRATAÇÃO",
    "HECCUS / MANTHUS SESSÃO CORTESIA": "HECCUS",
    "CO2 MÃOS (Sessão)": "CO2 MÃOS",
    "CO2 PESCOÇO (Sessão)": "CO2 PESCOÇO",
    "CO2 CICATRIZ (Sessão)": "CO2 CICATRIZ",
    "ENZIMAS PRÓ-CELL SESSÃO": "PRÓ-CELL",
    "ENZIMAS MELASMA SESSÃO": "ENZIMA MELASMA",
    "ENZIMAS PRÓ-BELLA SESSÃO": "PRÓ-BELLA",
    "CARBOXITERAPIA CORPORAL SESSÃO CORTESIA": "CARBOXITERAPIA",
    "PRÓ-SHAPE SESSÃO CORTESIA": "PRÓ-SHAPE",
    "Preenchimento 4ml (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "PRÓ-SKIN SESSÃO": "PREENCHIMENTO",
    "Preenchimento 2ml (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "SKINBOOSTER 2ML (DESATIVADO)": "PREENCHIMENTO",
    "Preenchimento 3ml (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "HIDRATAÇÃO FACIAL PINK DIAMOND SESSÃO": "HIDRATAÇÃO",
    "CO2 OLHEIRAS (Sessão)": "CO2 OLHEIRAS",
    "ENZIMAS MELASMA 4 SESSÕES [COMBO PARA MANCHAS]": "ENZIMA MELASMA",
    "CRIOLIPÓLISE (2 ÁREAS) (EXCLUSIVO PARA AGENDAMENTO)": "CRIOLIPÓLISE",
    "SKINBOOSTER 1ML (DESATIVADO)": "PREENCHIMENTO",
    "CRIOLIPÓLISE (1 ÁREA)": "CRIOLIPÓLISE",
    "LIMPEZA DE PELE SESSÃO EXCLUSIVO R$ 90": "LIMPEZA DE PELE",
    "PEELING QUÍMICO FACIAL SIMPLES SESSÃO (EXCLUSIVO PARA AGENDAMENTO) DESATIVADO": "PEELING QUÍMICO",
    "PEELING QUÍMICO CORPORAL SESSÃO (EXCLUSIVO PARA AGENDAMENTO) DESATIVADO": "PEELING QUÍMICO",
    "ULTRAFORMER INTERNO COXA (Sessão)": "ULTRAFORMER INTERNO COXA",
    "ULTRAFORMER MAÇÃ DO ROSTO (Sessão)": "ULTRAFORMER MAÇA DO ROSTO",
    "ULTRAFORMER FULLFACE (Sessão)": "ULTRAFORMER FULLFACE",
    "MASSAGEM PRÓ-DETOX 5 SESSÕES [COMBO GORDURA LOCALIZADA]": "DRENAGEM",
    "LIMPEZA DE PELE SESSÃO CORTESIA INDIQUE": "LIMPEZA DE PELE",
    "ULTRAFORMER FULLFACE + PESCOÇO (Sessão)": "ULTRAFORMER FULLFACE + PESCOÇO",
    "ULTRAFORMER PESCOÇO (Sessão)": "ULTRAFORMER PESCOÇO",
    "ULTRAFORMER PAPADA (Sessão)": "ULTRAFORMER PAPADA",
    "PREENCHIMENTO 1ML VOLYME / DEFYNE": "PREENCHIMENTO",
    "BOTOX EM DOBRO (100 Unidades)": "BOTOX POWER",
    "ENZIMAS PRÓ-LIPO SESSÃO (DESATIVADO)": "PRÓ-LIPO",
    "ULTRAFORMER OLHOS (Sessão)": "ULTRAFORMER OLHOS",
    "ENZIMAS PRÓ-CELL SESSÃO EXCLUSIVO PARA COLABORADOR": "PRÓ-CELL",
    "PREENCHIMENTO 4ML VOLYME / DEFYNE (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "CO2 ROSTO 3 SESSÕES [CRONOGRAMA DA PELE PERFEITA]": "CO2 ROSTO",
    "ULTRAFORMER GLUTEO (Sessão)": "ULTRAFORMER GLUTEO",
    "PREENCHIMENTO 3ML VOLYME / DEFYNE (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "ULTRAFORMER BRAÇO (Sessão)": "ULTRAFORMER BRAÇO",
    "HIDRATAÇÃO FACIAL PINK DIAMOND DE ANIVERSÁRIO": "HIDRATAÇÃO",
    "PREENCHIMENTO 2ML VOLYME / DEFYNE (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "SECAGEM DE VASINHOS (SESSÃO)": "SECAGEM",
    "ENZIMAS PRÓ-CELL SESSÃO (DESATIVADO)": "PRÓ-CELL",
    "DERMAROLLER ROSTO 3 SESSÕES [COMBO PELE RENOVADA]": "DERMAROLLER",
    "ENZIMAS PRÓ-FIT SESSÃO EXCLUSIVO PARA COLABORADOR": "PRÓ-FIT",
    "PRÓ-SHAPE 5 SESSÕES [COMBO BUMBUM PERFEITO]": "PRÓ-SHAPE",
    "ENZIMAS PRÓ-FIT SESSÃO (DESATIVADO)": "PRÓ-FIT",
    "ENZIMAS PRÓ-FIRM SESSÃO (DESATIVADO)": "PRÓ-FIRM",
    "CRIOLIPÓLISE 2 SESSÕES [COMBO GORDURA LOCALIZADA]": "CRIOLIPÓLISE",
    "PEELING QUÍMICO 3 SESSÕES [COMBO PELE RENOVADA]": "PEELING QUÍMICO",
    "CRIOLIPÓLISE 2 SESSÕES [COMBO PRÓ-SLIM]": "CRIOLIPÓLISE",
    "LAVIEEN ROSTO COMPLETO SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "LAVIEEN",
    "LAVIEEN CORPORAL S": "LAVIEEN",
    "LAVIEEN BB LASER SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "LAVIEEN",
    "LAVIEEN ROSTO COMPLETO SESSÃO": "LAVIEEN",
    "LAVIEEN CORPORAL SESSÃO": "LAVIEEN",
    "ENZIMAS CAPILAR SESSÃO": "PRÓ-MESO",
    "ENZIMAS DE GORDURA DE PAPADA/AXILAR SESSÃO": "PRÓ-BELLA",
    "ENZIMAS DE GORDURA SESSÃO": "PRÓ-LIPO",
    "ENZIMAS PRÓ-FIRM SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "ENZIMA MELASMA",
    "ENZIMAS DE MELASMA SESSÃO": "ENZIMA MELASMA",
    "ENZIMAS PRÓ-FIT SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "PRÓ-FIT",
    "ENZIMAS PRÓ-CELL SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "PRÓ-CELL",
    "PRÓ-SKIN SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "LAVIEEN ROSTO SESSÃO CORTESIA": "LAVIEEN",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (1H)": "DRENAGEM",
    "LIMPEZA DE PELE SESSÃO EXCLUSIVO R$ 50": "LIMPEZA DE PELE",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (30 MIN)": "DRENAGEM (30 MIN)",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO CORTESIA (30MIN)": "DRENAGEM (30 MIN)",
    "RADIESSE 1 FRASCO": "RADIESSE",
    "LAVIEEN BB LASER SESSÃO": "LAVIEEN",
    "CO2 CICATRIZ (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 CICATRIZ",
    "CO2 COLO (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 COLO",
    "CO2 ROSTO (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 ROSTO",
    "CO2 OLHEIRAS (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 OLHEIRAS",
    "CO2 PESCOÇO (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 PESCOÇO",
    "CO2 ROSTO 3 SESSÕES [CRONOGRAMA DA PELE PERFEITA] (EXCLUSIVO PARA AGENDAMENTO)": "CO2 ROSTO",
    "ULTRAFORMER FULLFACE + PESCOÇO + PAPADA (Sessão) (Exclusivo para Agendamento)": "ULTRAFORMER FULLFACE + PESCOÇO + PAPADA",
    "CO2 MÃOS (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 MÃOS",
    "CRIOLIPÓLISE (2 ÁREAS)": "CRIOLIPÓLISE",
    "LAVIEEN ( 1 SESSÃO) [BELEZA EM DOBRO] (Exclusivo para Agendamento)": "LAVIEEN",
    "CRIOLIPÓLISE (1 ÁREA) [BELEZA EM DOBRO] (Exclusivo para Agendamento": "CRIOLIPÓLISE",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (1H) [BELEZA EM DOBRO] (Exclusivo para Agendamento)": "DRENAGEM",
    "PEELING QUÍMICO 3 SESSÕES [CRONOGRAMA DA PELE PERFEITA]": "PEELING QUÍMICO",
    "LAVIEEN OLHOS SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "LAVIEEN",
    "ULTRAFORMER FULLFACE + PESCOÇO + PAPADA (Sessão)": "ULTRAFORMER FULLFACE + PESCOÇO + PAPADA",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (1H)": "DRENAGEM",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO CORTESIA (30MIN)": "DRENAGEM (30 MIN)",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (30 MIN)": "DRENAGEM (30 MIN)",
    "LAVIEEN ROSTO COMPLETO SESSÃO": "LAVIEEN",
    "PRÓ-SHAPE SESSÃO (PACOTE 10 SESSÕES)": "PRÓ-SHAPE",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (1H) (PACOTE 10 SESSÕES)": "DRENAGEM",
    "PEELING DE DIAMANTE SESSÃO CORTESIA": "PEELING DE DIAMANTE",
    "HIDRATAÇÃO FACIAL PINK DIAMOND SESSÃO CORTESIA": "HIDRATAÇÃO",
    "RETORNO INJETÁVEIS E INVASIVOS": "UNMAPPED",
    "LAVIEEN ROSTO SESSÃO CORTESIA": "LAVIEEN",
    "LAVIEEN CORPORAL SESSÃO": "LAVIEEN",
    "LAVIEEN (PACOTE 3 SESSÕES)": "LAVIEEN",
    "PRÓ-SHAPE SESSÃO": "PRÓ-SHAPE",
    "CARBOXITERAPIA CORPORAL SESSÃO": "CARBOXITERAPIA",
    "LIMPEZA DE PELE SESSÃO EXCLUSIVO R$ 90": "LIMPEZA DE PELE",
    "HECCUS / MANTHUS SESSÃO": "HECCUS",
    "DERMAROLLER ROSTO (Sessão)": "DERMAROLLER",
    "ENZIMAS DE GORDURA SESSÃO": "PRÓ-LIPO",
    "HECCUS / MANTHUS SESSÃO CORTESIA": "HECCUS",
    "PEELING QUÍMICO SESSÃO": "PEELING QUÍMICO",
    "HECCUS / MANTHUS SESSÃO (PACOTE 10 SESSÕES)": "HECCUS",
    "ULTRAFORMER FULLFACE (Sessão)": "ULTRAFORMER FULLFACE",
    "ULTRAFORMER PAPADA (Sessão)": "ULTRAFORMER PAPADA",
    "ULTRAFORMER PESCOÇO (Sessão)": "ULTRAFORMER PESCOÇO",
    "CARBOXITERAPIA CORPORAL SESSÃO (PACOTE 10 SESSÕES)": "CARBOXITERAPIA",
    "CO2 CICATRIZ (Sessão) (JARDINS)": "CO2 CICATRIZ",
    "RETOQUE TOXINA BOTULÍNICA": "RETOQUE",
    "ULTRAFORMER MAÇÃ DO ROSTO (Sessão)": "ULTRAFORMER MAÇA DO ROSTO",
    "CO2 ROSTO (Sessão) (JARDINS)": "CO2 ROSTO",
    "LIMPEZA DE PELE SESSÃO CORTESIA": "LIMPEZA DE PELE",
    "HIDROLIPO SESSÃO (VILA MASCOTE)": "UNMAPPED",
    "LIMPEZA DE PELE SESSÃO EXCLUSIVO R$ 50 (EXCLUSIVO PARA AGENDAMENTO)": "LIMPEZA DE PELE",
    "BOTOX POWER (50 Unidades)": "BOTOX POWER",
    "ENZIMAS PRÓ-LIPO SESSÃO (DESATIVADO)": "PRÓ-LIPO",
    "CO2 PESCOÇO (Sessão) (JARDINS)": "CO2 PESCOÇO",
    "RADIOFREQUÊNCIA CORPORAL SESSÃO": "RADIOFREQUÊNCIA",
    "SECAGEM DE VASINHOS (SESSÃO)": "SECAGEM",
    "RADIOFREQUÊNCIA CORPORAL SESSÃO (PACOTE 10 SESSÕES)": "RADIOFREQUÊNCIA",
    "PREENCHIMENTO 1ML": "PREENCHIMENTO",
    "ENZIMA GLÚTEO MAX SESSÃO":"GLÚTEO MAX",
    "RADIOFREQUÊNCIA SESSÃO CORTESIA": "RADIOFREQUÊNCIA",
    "SCULPTRA 1 FRASCO": "SCULPTRA",
    "ULTRAFORMER INTERNO COXA (Sessão)": "ULTRAFORMER INTERNO COXA",
    "BOTOX LIGHT (25 Unidades)": "BOTOX LIGHT",
    "ENZIMAS CAPILAR SESSÃO": "PRÓ-MESO",
    "BOTOX POWER (50 Unidades) + LAVIEEN SESSÃO CORTESIA": "BOTOX POWER",
    "ENZIMAS GORDURA SESSÃO (VILA MASCOTE)": "PRÓ-LIPO",
    "Preenchimento 2ml (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "ULTRAFORMER OLHOS (Sessão)": "ULTRAFORMER OLHOS",
    "BUMBUM PERFEITO (40ml + 2 SESSÕES SCULPTRA)" : "BUMBUM PERFEITO",
    "UP BUMBUM (20ml + 1 SESSÃO SCULPTRA)" : "UP BUMBUM",
    "PREENCHIMENTO CORPORAL 2 ML" : "PREENCHIMENTO CORPORAL",
    "PRÓ-SERUM": "PRÓ-SÉRUM",
    "LAVIEEN ( 1 SESSÃO) [BELEZA EM DOBRO] (Exclusivo para Agendamento)": "LAVIEEN",
    "CO2 CICATRIZ (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 CICATRIZ",
    "LAVIEEN BB LASER SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "LAVIEEN",
    "CRIOLIPÓLISE (1 ÁREA) [BELEZA EM DOBRO] (Exclusivo para Agendamento": "CRIOLIPÓLISE",
    "CO2 MÃOS (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 MÃOS",
    "CO2 COLO (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 COLO",
    "PÓS TRATAMENTO": "PÓS TRATAMENTO",
    "BOTOX POWER (50 Unidades) + LAVIEEN SESSÃO CORTESIA": "BOTOX POWER",
    "PRÉ TRATAMENTO": "PRÉ TRATAMENTO",
    "ENZIMAS PRÓ-FIRM SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "ENZIMAS PRÓ-FIRM",
    "ULTRAFORMER FULLFACE + PESCOÇO + PAPADA (Sessão) (Exclusivo para Agendamento)": "ULTRAFORMER FULLFACE + PESCOÇO + PAPADA",
    "CO2 OLHEIRAS (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 OLHEIRAS",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (1H) [BELEZA EM DOBRO] (Exclusivo para Agendamento)": "DRENAGEM",
    "LAVIEEN CORPORAL SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "LAVIEEN CORPORAL",
    "PREENCHIMENTO 3ML VOLYME / DEFYNE (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "CO2 PESCOÇO (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 PESCOÇO",
    "CO2 ROSTO 3 SESSÕES [CRONOGRAMA DA PELE PERFEITA] (EXCLUSIVO PARA AGENDAMENTO)": "CO2 ROSTO",
    "ROSTO FEMININO SESSÃO": "ROSTO FEMININO",
    "ENZIMAS PRÓ-CELL SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "ENZIMAS PRÓ-CELL",
    "CRIOLIPÓLISE (1 ÁREA) [BELEZA EM DOBRO] (Exclusivo para Agendamento)": "CRIOLIPÓLISE",
    "CO2 CICATRIZ (Sessão) (JARDINS)": "CO2 CICATRIZ",
    "CO2 ROSTO (Sessão) (JARDINS)": "CO2 ROSTO",
    "CO2 COLO (Sessão) (JARDINS)": "CO2 COLO",
    "CO2 MÃOS (Sessão) (JARDINS)": "CO2 MÃOS",
    "CO2 PESCOÇO (Sessão) (JARDINS)": "CO2 PESCOÇO",
    "CO2 OLHEIRAS (Sessão) (JARDINS)": "CO2 OLHEIRAS",
    "LAVIEEN CORPORAL\xa0SESSÃO": "LAVIEEN",
    "LAVIEEN OLHOS SESSÃO" : "LAVIEEN",
    "PEELING QUÍMICO 3 SESSÕES [DESCONTO PROGRESSIVO]" : "PEELING QUÍMICO",
    'AVALIAÇÃO INJETÁVEIS E INVASIVOS' : 'AVALIAÇÃO',
    'Remoção de Tatuagem 121 a 255 cm²' : 'TATUAGEM',
    'Remoção de Tatuagem 36 a 120 cm²': 'TATUAGEM',
    'AVALIAÇÃO ESTÉTICA': 'AVALIAÇÃO',
    'Remoção de Tatuagem 1 a 35 cm²': 'TATUAGEM',
    'LUZ PULSADA SESSÃO': 'LUZ PULSADA',
    'REMOÇÃO DE TATUAGEM SESSÃO CORTESIA (OSASCO)': 'TATUAGEM',
    'DEPILAÇÃO SESSÃO CORTESIA (OSASCO)': 'DEPILAÇÃO',
    'VIRILHA COMPLETA SESSÃO': 'DEPILAÇÃO',
    'PERIANAL SESSÃO': 'DEPILAÇÃO',
    'AXILAS SESSÃO': 'DEPILAÇÃO',
    '1/2 PERNA SESSÃO': 'DEPILAÇÃO',
    'PERNAS COMPLETAS SESSÃO': 'DEPILAÇÃO',
    '1/2 ROSTO SESSÃO': 'DEPILAÇÃO',
    'AVALIAÇÃO DEPILAÇÃO': 'DEPILAÇÃO',
    'BUÇO SESSÃO': 'DEPILAÇÃO',
    'GLÚTEO SESSÃO': 'DEPILAÇÃO',
    'Remoção de Tatuagem 256 a 440 cm²': 'TATUAGEM',
    'Remoção de Tatuagem 676 a 900 cm²': 'TATUAGEM',
    'BRAÇOS COMPLETOS SESSÃO': 'DEPILAÇÃO',
    'PEITO SESSÃO': 'DEPILAÇÃO',
    'AREOLA MAMILO SESSÃO (EXCLUSIVO PARA AGENDAMENTO)': 'DEPILAÇÃO',
    'ABDOMEN COMPLETO SESSÃO': 'DEPILAÇÃO',
    'BIOIMPEDÂNCIA SESSÃO': 'BIOIMPEDÂNCIA',
    'BARBA COMPLETA SESSÃO': 'DEPILAÇÃO',
    'VIRILHA CAVADA SESSÃO': 'DEPILAÇÃO',
    'Remoção de Tatuagem 441 a 675 cm²': 'TATUAGEM',
    'Vale Presente': 'VALE PRESENTE',
    'PESCOÇO SESSÃO': 'DEPILAÇÃO',
    'NUCA SESSÃO': 'DEPILAÇÃO',
    'VIRILHA + PERIANAL (EXCLUSIVO PARA AGENDAMENTO)': 'DEPILAÇÃO',
    'PÉS SESSÃO': 'DEPILAÇÃO',
    'PERNAS COMPLETAS + VIRILHA + AXILAS + PERIANAL (EXCLUSIVO PARA AGENDAMENTO)': 'DEPILAÇÃO',
    'ENTRE PERNAS SESSÃO (EXCLUSIVO PARA AGENDAMENTO)': 'DEPILAÇÃO',
    'VIRILHA + AXILAS + 1/2 PERNA + PERIANAL (EXCLUSIVO PARA AGENDAMENTO)': 'DEPILAÇÃO',
    'Vicae': 'VICAE',
    'VIRILHA + AXILAS + PERIANAL (EXCLUSIVO PARA AGENDAMENTO)': 'DEPILAÇÃO',
    'LIPO SEM CORTES (VILA MASCOTE)': 'UNMAPPED',
    'MANTA DETOX SESSÃO (VILA MASCOTE)': 'UNMAPPED',
    'CORRENTE RUSSA SESSÃO (VILA MASCOTE)': 'UNMAPPED',
    'AVALIAÇÃO TATUAGEM': 'AVALIAÇÃO',
    'OZÔNIO SESSÃO (VILA MASCOTE)': 'UNMAPPED',
    'ENZIMAS PRÓ-FIT SESSÃO (VILA MASCOTE)': 'UNMAPPED',
    'ENZIMAS PRÓ-FIRM (VILA MASCOTE)': 'UNMAPPED',
    'LAVIEEN ( 1 SESSÃO) [BELEZA EM DOBRO]': 'LAVIEEN',
    'RESERVA DE HORÁRIO': 'UNMAPPED',
    'VIRILHA + AXILAS (EXCLUSIVO PARA AGENDAMENTO)': 'DEPILAÇÃO',
    'HIDRATAÇÃO FACIAL PURPLE SHINE SESSÃO CORTESIA': 'HIDRATAÇÃO',
    'MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (1H) [BELEZA EM DOBRO]' : 'DRENAGEM',
    'CRIOLIPÓLISE (1 ÁREA) [BELEZA EM DOBRO]' : 'CRIOLIPÓLISE',
    'ULTRASSOM MICRO E MACRO FOCADO OLHOS (Sessão)' : "ULTRAFORMER OLHOS",
    'ULTRASSOM MICRO E MACRO FOCADO PAPADA (Sessão)' : "ULTRAFORMER PAPADA",
    'ULTRASSOM MICRO E MACRO FOCADO FULLFACE (Sessão)' : "ULTRAFORMER FULLFACE",
    'ULTRASSOM MICRO E MACRO FOCADO PESCOÇO (Sessão)' : "ULTRAFORMER PESCOÇO",
    'ULTRASSOM MICRO E MACRO FOCADO MAÇÃ DO ROSTO (Sessão)' : "ULTRAFORMER MAÇA DO ROSTO",
    'ULTRASSOM MICRO E MACRO FOCADO FULLFACE + PESCOÇO (Sessão)' : "ULTRAFORMER FULLFACE + PESCOÇO",
    'ULTRASSOM MICRO E MACRO FOCADO GLUTEO (Sessão)' : "ULTRAFORMER GLUTEO",
    'ULTRASSOM MICRO E MACRO FOCADO INTERNO COXA (Sessão)' : "ULTRAFORMER INTERNO COXA",
    'ULTRASSOM MICRO E MACRO FOCADO BRAÇO (Sessão)' : "ULTRAFORMER BRAÇO",
    'ULTRASSOM MICRO E MACRO FOCADO COLO (Sessão)' : "ULTRAFORMER COLO",
    'ULTRASSOM MICRO E MACRO FOCADO ABDOME (1 QUADRANTE) (Sessão)' : "ULTRAFORMER ABDOME",
    'HIDRATAÇÃO FACIAL PURPLE SHINE SESSÃO' : 'HIDRATAÇÃO',
    'LAVIEEN SESSÃO ANIVERSÁRIO PRÓ-CORPO 2025': 'LAVIEEN',
    'BOTOX PRIME (40 unidades)' : 'BOTOX PRIME'
   }



Sales_dic = {
    "CRIOLIPÓLISE (1 ÁREA)": "CRIOLIPÓLISE",
    "LIMPEZA DE PELE SESSÃO EXCLUSIVO R$ 50 (EXCLUSIVO PARA AGENDAMENTO)": "LIMPEZA DE PELE",
    "LIMPEZA DE PELE SESSÃO CORTESIA": "LIMPEZA DE PELE",
    "PEELING DE DIAMANTE SESSÃO": "PEELING DE DIAMANTE",
    "LIMPEZA DE PELE SESSÃO EXCLUSIVO R$ 90": "LIMPEZA DE PELE",
    "Remoção de Tatuagem 1 a 35 cm²": "DEPILACAO",
    "BOTOX POWER (50 Unidades)": "BOTOX POWER",
    "PREENCHIMENTO 1ML": "PREENCHIMENTO",
    "BOTOX LIGHT (25 Unidades)": "BOTOX LIGHT",
    "SCULPTRA 1 FRASCO": "SCULPTRA",
    "CO2 CICATRIZ (Sessão)": "CO2 CICATRIZ",
    "PRÓ-SHAPE SESSÃO": "PRÓ-SHAPE",
    "ENZIMAS PRÓ-MESO SESSÃO": "PRÓ-MESO",
    "CO2 OLHEIRAS (Sessão)": "CO2 OLHEIRAS",
    "LIMPEZA DE PELE SESSÃO CORTESIA INDIQUE": "LIMPEZA DE PELE",
    "CARBOXITERAPIA CORPORAL SESSÃO": "CARBOXITERAPIA",
    "DRENAGEM LINFÁTICA SESSÃO": "DRENAGEM",
    "PEELING DE DIAMANTE SESSÃO CORTESIA": "PEELING DE DIAMANTE",
    "LUZ PULSADA SESSÃO": "LUZ PULSADA",
    "SECAGEM DE VASINHOS (SESSÃO) (EXCLUSIVO PARA AGENDAMENTO)": "SECAGEM",
    "PEELING QUÍMICO SESSÃO": "PEELING QUÍMICO",
    "ENZIMAS PRÓ-LIPO SESSÃO": "PRÓ-LIPO",
    "HECCUS / MANTHUS SESSÃO": "HECCUS",
    "Vale Presente": "VALE PRESENTE",
    "Vicae": "VICAE",
    "MASSAGEM PRÓ-DETOX SESSÃO CORTESIA": "DRENAGEM",
    "HIDRATAÇÃO FACIAL PINK DIAMOND SESSÃO CORTESIA": "HIDRATAÇÃO",
    "CO2 ROSTO (Sessão)": "CO2 ROSTO",
    "ENZIMAS PRÓ-CELL SESSÃO": "PRÓ-CELL",
    "RADIOFREQUÊNCIA CORPORAL SESSÃO": "RADIOFREQUÊNCIA",
    "RADIOFREQUÊNCIA FACIAL SESSÃO": "RADIOFREQUÊNCIA",
    "MASSAGEM PRÓ-DETOX SESSÃO": "DRENAGEM",
    "ENZIMAS MELASMA SESSÃO": "ENZIMA MELASMA",
    "Preenchimento 2ml (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "PRÓ-SKIN SESSÃO": "PREENCHIMENTO",
    "ENZIMAS PRÓ-FIT SESSÃO": "PRÓ-FIT",
    "DERMAROLLER ROSTO (Sessão)": "DERMAROLLER",
    "ULTRAFORMER FULLFACE + PESCOÇO (Sessão)": "ULTRAFORMER FULLFACE + PESCOÇO",
    "LIMPEZA DE PELE SESSÃO": "LIMPEZA DE PELE",
    "ULTRAFORMER FULLFACE (Sessão)": "ULTRAFORMER FULLFACE",
    "ULTRAFORMER PAPADA (Sessão)": "ULTRAFORMER PAPADA",
    "CARBOXITERAPIA FACIAL SESSÃO": "CARBOXITERAPIA",
    "PREENCHIMENTO 1ML VOLYME / DEFYNE": "PREENCHIMENTO",
    "BOTOX EM DOBRO (100 Unidades)": "BOTOX POWER",
    "ENZIMAS PRÓ-BELLA SESSÃO": "PRÓ-BELLA",
    "Preenchimento 3ml (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "CARBOXITERAPIA CORPORAL SESSÃO CORTESIA": "CARBOXITERAPIA",
    "ENZIMAS MELASMA 4 SESSÕES [COMBO PARA MANCHAS]": "ENZIMA MELASMA",
    "PEELING QUÍMICO 3 SESSÕES [COMBO PARA MANCHAS]": "PEELING QUÍMICO",
    "BIOIMPEDÂNCIA SESSÃO": "BIOIMPEDÂNCIA",
    "CO2 COLO (Sessão)": "CO2 COLO",
    "PRÓ-SHAPE 5 SESSÕES [COMBO BUMBUM PERFEITO]": "PRÓ-SHAPE",
    "ENZIMAS PRÓ-CELL 5 SESSÕES [COMBO BUMBUM PERFEITO]": "PRÓ-CELL",
    "QUEIXO SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "DEPILACAO",
    "HIDRATAÇÃO FACIAL PINK DIAMOND SESSÃO": "HIDRATAÇÃO",
    "ULTRAFORMER OLHOS (Sessão)": "ULTRAFORMER OLHOS",
    "AXILAS SESSÃO": "DEPILACAO",
    "PERNAS COMPLETAS SESSÃO": "DEPILACAO",
    "VIRILHA COMPLETA SESSÃO": "DEPILACAO",
    "DERMAROLLER ROSTO 3 SESSÕES [COMBO PELE RENOVADA]": "DERMAROLLER",
    "SKINBOOSTER 1ML (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "ULTRAFORMER MAÇÃ DO ROSTO (Sessão)": "ULTRAFORMER MAÇA DO ROSTO",
    "HIDRATAÇÃO FACIAL RUBY SESSÃO": "HIDRATAÇÃO",
    "CO2 MÃOS (Sessão)": "CO2 MÃOS",
    "ULTRAFORMER PESCOÇO (Sessão)": "ULTRAFORMER PESCOÇO",
    "DRENAGEM FACIAL SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "DRENAGEM",
    "RADIOFREQUÊNCIA SESSÃO CORTESIA": "RADIOFREQUÊNCIA",
    "HECCUS / MANTHUS SESSÃO CORTESIA": "HECCUS",
    "ENZIMAS PRÓ-LIPO 5 SESSÕES [COMBO GORDURA LOCALIZADA]": "PRÓ-LIPO",
    "CRIOLIPÓLISE 2 SESSÕES [COMBO GORDURA LOCALIZADA]": "CRIOLIPÓLISE",
    "ANESTÉSICO TÓPICO": "DEPILACAO",
    "BIOIMPEDÂNCIA SESSÃO CORTESIA": "BIOIMPEDÂNCIA",
    "PEELING QUÍMICO FACIAL SIMPLES SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "PEELING QUÍMICO",
    "ENZIMAS PRÓ-FIRM SESSÃO": "PRÓ-FIRM",
    "ULTRAFORMER BRAÇO (Sessão)": "ULTRAFORMER BRAÇO",
    "CO2 PESCOÇO (Sessão)": "CO2 PESCOÇO",
    "PEELING QUÍMICO CORPORAL SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "PEELING QUÍMICO",
    "CRIOLIPÓLISE (2 ÁREAS) (EXCLUSIVO PARA AGENDAMENTO)": "CRIOLIPÓLISE",
    "PREENCHIMENTO 4ML VOLYME / DEFYNE (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "PRÓ-SHAPE SESSÃO CORTESIA": "PRÓ-SHAPE",
    "ULTRAFORMER INTERNO COXA (Sessão)": "ULTRAFORMER INTERNO COXA",
    "MASSAGEM PRÓ-DETOX 5 SESSÕES [COMBO GORDURA LOCALIZADA]": "DRENAGEM",
    "ULTRAFORMER GLUTEO (Sessão)": "ULTRAFORMER GLUTEO",
    "SECAGEM DE VASINHOS (SESSÃO)": "SECAGEM",
    "1/2 BRAÇO SESSÃO": "DEPILACAO",
    "HIALURONIDASE": "HIALURONIDASE",
    "PREENCHIMENTO 2ML VOLYME / DEFYNE (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "PERIANAL SESSÃO": "DEPILACAO",
    "1/2 PERNA SESSÃO": "DEPILACAO",
    "SKINBOOSTER 1ML (DESATIVADO)": "PREENCHIMENTO",
    "PEELING QUÍMICO FACIAL SIMPLES SESSÃO (EXCLUSIVO PARA AGENDAMENTO) DESATIVADO": "PEELING QUÍMICO",
    "CO2 ROSTO 3 SESSÕES [CRONOGRAMA DA PELE PERFEITA]": "CO2 ROSTO",
    "Preenchimento 4ml (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "PEELING QUÍMICO 3 SESSÕES [COMBO PELE RENOVADA]": "PEELING QUÍMICO",
    "PEELING QUÍMICO 3 SESSÕES [DESCONTO PROGRESSIVO]": "PEELING QUÍMICO",
    "PEELING QUÍMICO 2 SESSÕES [DESCONTO PROGRESSIVO]": "PEELING QUÍMICO",
    "PEELING QUÍMICO 3 SESSÕES [CRONOGRAMA DA PELE PERFEITA]": "PEELING QUÍMICO",
    "LAVIEEN ROSTO COMPLETO SESSÃO": "LAVIEEN",
    "LAVIEEN BB LASER SESSÃO": "LAVIEEN",
    "LAVIEEN OLHOS SESSÃO": "LAVIEEN",
    "AXILAS SESSÃO CORTESIA": "DEPILACAO",
    "LAVIEEN CORPORAL SESSÃO": "LAVIEEN",
    "CRIOLIPÓLISE 2 SESSÕES [COMBO PRÓ-SLIM]": "CRIOLIPÓLISE",
    "BRAÇOS COMPLETOS SESSÃO": "DEPILACAO",
    "PERNAS COMPLETAS + AXILAS + VIRILHA (EXCLUSIVO PARA AGENDAMENTO)": "DEPILACAO",
    "BUÇO SESSÃO": "DEPILACAO",
    "1/2 ABDÔMEN SESSÃO": "DEPILACAO",
    "1/2 ROSTO SESSÃO": "DEPILACAO",
    "LAVIEEN ROSTO COMPLETO SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "LAVIEEN",
    "GLÚTEO SESSÃO": "DEPILACAO",
    "PEITO SESSÃO": "DEPILACAO",
    "ABDOMEN COMPLETO SESSÃO": "DEPILACAO",
    "PESCOÇO SESSÃO": "DEPILACAO",
    "VIRILHA CAVADA SESSÃO": "DEPILACAO",
    "ENZIMAS DE GORDURA DE PAPADA/AXILAR SESSÃO": "PRÓ-BELLA",
    "ENZIMAS DE GORDURA SESSÃO": "PRÓ-LIPO",
    "ENZIMAS CAPILAR SESSÃO": "PRÓ-MESO",
    "ENZIMAS PRÓ-FIT SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "PRÓ-FIT",
    "PRÓ-SKIN SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "PREENCHIMENTO",
    "LAVIEEN ROSTO SESSÃO CORTESIA": "LAVIEEN",
    "RADIESSE 1 FRASCO": "RADIESSE",
    "ENZIMAS DE MELASMA SESSÃO": "ENZIMA MELASMA",
    "MASSAGEM PRÓ-DETOX/DRENAGEM LINFÁTICA SESSÃO": "DRENAGEM",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO CORTESIA": "DRENAGEM",
    "ULTRAFORMER FULLFACE + PESCOÇO + PAPADA (Sessão)": "ULTRAFORMER FULLFACE + PESCOÇO + PAPADA",
    "BARBA COMPLETA SESSÃO": "DEPILACAO",
    "LIMPEZA DE PELE SESSÃO EXCLUSIVO R$ 50": "LIMPEZA DE PELE",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (1H)": "DRENAGEM",
    "AREOLA MAMILO SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "DEPILACAO",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (30 MIN)": "DRENAGEM 30 MIN",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO CORTESIA (30MIN)": "DRENAGEM 30 MIN",
    "CRIOLIPÓLISE (2 ÁREAS)": "CRIOLIPÓLISE",
    "LAVIEEN ( 1 SESSÃO) [BELEZA EM DOBRO]": "LAVIEEN",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (1H) [BELEZA EM DOBRO]": "DRENAGEM",
    "CRIOLIPÓLISE (1 ÁREA) [BELEZA EM DOBRO]": "CRIOLIPÓLISE",
    "CO2 ROSTO (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 ROSTO",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (1H) (PACOTE 10 SESSÕES)": "DRENAGEM",
    "LAVIEEN (PACOTE 3 SESSÕES)": "LAVIEEN",
    "PRÓ-SERUM": "PRÓ-SÉRUM",
    "ENZIMA GLÚTEO MAX SESSÃO": "GLÚTEO MAX",
    "RADIOFREQUÊNCIA CORPORAL SESSÃO (PACOTE 10 SESSÕES)": "RADIOFREQUÊNCIA",
    "CARBOXITERAPIA CORPORAL SESSÃO (PACOTE 10 SESSÕES)": "CARBOXITERAPIA",
    "HECCUS / MANTHUS SESSÃO (PACOTE 10 SESSÕES)": "HECCUS",
    "LAVIEEN CORPORAL\xa0SESSÃO": "LAVIEEN",
    "PRÓ-SHAPE SESSÃO (PACOTE 10 SESSÕES)": "PRÓ-SHAPE",
    "BUMBUM PERFEITO (40ml + 2 SESSÕES SCULPTRA)" : "BUMBUM PERFEITO",
    "UP BUMBUM (20ml + 1 SESSÃO SCULPTRA)" : "UP BUMBUM",
    "PREENCHIMENTO CORPORAL 2 ML" : "PREENCHIMENTO CORPORAL",
    "LAVIEEN CORPORAL\xa0SESSÃO": "LAVIEEN",
    "LAVIEEN OLHOS SESSÃO" : "LAVIEEN",
    "PEELING QUÍMICO 3 SESSÕES [DESCONTO PROGRESSIVO]" : "PEELING QUÍMICO",
    "BOTOX POWER (50 Unidades) + LAVIEEN SESSÃO CORTESIA": "BOTOX POWER",
    "CO2 CICATRIZ (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 CICATRIZ",
    "LAVIEEN ( 1 SESSÃO) [BELEZA EM DOBRO] (Exclusivo para Agendamento)": "LAVIEEN",
    "CRIOLIPÓLISE (1 ÁREA) [BELEZA EM DOBRO] (Exclusivo para Agendamento": "CRIOLIPÓLISE",
    "CO2 PESCOÇO (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 PESCOÇO",
    "CO2 COLO (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 COLO",
    "MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (1H) [BELEZA EM DOBRO] (Exclusivo para Agendamento)": "DRENAGEM",
    "CO2 MÃOS (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 MÃOS",
    "CO2 OLHEIRAS (Sessão) (EXCLUSIVO PARA AGENDAMENTO)": "CO2 OLHEIRAS",
    "ENZIMAS PRÓ-FIRM SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "PRÓ-FIRM",
    "ENZIMAS PRÓ-CELL SESSÃO (EXCLUSIVO PARA AGENDAMENTO)": "PRÓ-CELL",
    "ULTRAFORMER FULLFACE + PESCOÇO + PAPADA (Sessão) (Exclusivo para Agendamento)": "ULTRAFORMER FULLFACE + PESCOÇO + PAPADA",
    "CRIOLIPÓLISE (1 ÁREA) [BELEZA EM DOBRO] (Exclusivo para Agendamento)": "CRIOLIPÓLISE",
    "CO2 ROSTO (Sessão) (JARDINS)": "CO2 ROSTO",
    "CO2 OLHEIRAS (Sessão) (JARDINS)": "CO2 OLHEIRAS",
    "CO2 CICATRIZ (Sessão) (JARDINS)": "CO2 CICATRIZ",
    "CO2 COLO (Sessão) (JARDINS)": "CO2 COLO",
    'CO2 MÃOS (Sessão) (JARDINS)': 'CO2 MÃOS',
    'CO2 PESCOÇO (Sessão) (JARDINS)': 'CO2 PESCOÇO',
    'Vale Presente' : 'VALE PRESENTE',
    'Vicae' : 'VICAE',
    'AVALIAÇÃO ESTÉTICA' : 'AVALIAÇÃO',
    'HIDRATAÇÃO FACIAL PURPLE SHINE SESSÃO CORTESIA': 'HIDRATAÇÃO',
    'MASSAGEM MODELADORA/DRENAGEM LINFÁTICA SESSÃO (1H) [BELEZA EM DOBRO]' : 'DRENAGEM',
    'CRIOLIPÓLISE (1 ÁREA) [BELEZA EM DOBRO]' : 'CRIOLIPÓLISE',
    'ULTRASSOM MICRO E MACRO FOCADO OLHOS (Sessão)' : "ULTRAFORMER OLHOS",
    'ULTRASSOM MICRO E MACRO FOCADO PAPADA (Sessão)' : "ULTRAFORMER PAPADA",
    'ULTRASSOM MICRO E MACRO FOCADO FULLFACE (Sessão)' : "ULTRAFORMER FULLFACE",
    'ULTRASSOM MICRO E MACRO FOCADO PESCOÇO (Sessão)' : "ULTRAFORMER PESCOÇO",
    'ULTRASSOM MICRO E MACRO FOCADO MAÇÃ DO ROSTO (Sessão)' : "ULTRAFORMER MAÇA DO ROSTO",
    'ULTRASSOM MICRO E MACRO FOCADO FULLFACE + PESCOÇO (Sessão)' : "ULTRAFORMER FULLFACE + PESCOÇO",
    'ULTRASSOM MICRO E MACRO FOCADO GLUTEO (Sessão)' : "ULTRAFORMER GLUTEO",
    'ULTRASSOM MICRO E MACRO FOCADO INTERNO COXA (Sessão)' : "ULTRAFORMER INTERNO COXA",
    'ULTRASSOM MICRO E MACRO FOCADO BRAÇO (Sessão)' : "ULTRAFORMER BRAÇO",
    'ULTRASSOM MICRO E MACRO FOCADO COLO (Sessão)' : "ULTRAFORMER COLO",
    'ULTRASSOM MICRO E MACRO FOCADO ABDOME (1 QUADRANTE) (Sessão)' : "ULTRAFORMER ABDOME",
    'HIDRATAÇÃO FACIAL PURPLE SHINE SESSÃO' : 'HIDRATAÇÃO',
    'LAVIEEN SESSÃO ANIVERSÁRIO PRÓ-CORPO 2025': 'LAVIEEN',
    'BOTOX PRIME (40 unidades)' : 'BOTOX PRIME',
    'PÉS SESSÃO' : 'DEPILACAO',
    'ROSTO FEMININO SESSÃO' : 'DEPILACAO'
    
   }

Month_dic = {
    1: 'Janeiro',
    2: 'Fevereiro',
    3: 'Março',
    4: 'Abril',
    5: 'Maio',
    6: 'Junho',
    7: 'Julho',
    8: 'Agosto',
    9: 'Setembro',
    10: 'Outubro',
    11: 'Novembro',
    12: 'Dezembro'
}


duration_dic = {
  'BOTOX LIGHT': '00:30:00',
  'BOTOX POWER': '00:30:00',
  'CARBOXITERAPIA': '00:30:00',
  'CO2 CICATRIZ': '00:10:00',
  'CO2 COLO': '00:20:00',
  'CO2 MÃOS': '00:10:00',
  'CO2 OLHEIRAS': '00:10:00',
  'CO2 PESCOÇO': '00:20:00',
  'CO2 ROSTO': '00:30:00',
  'CRIOLIPÓLISE': '01:00:00',
  'DERMAROLLER': '00:30:00',
  'DRENAGEM': '01:00:00',
  'DRENAGEM 30 MIN' : '00:30:00',
  'DRENAGEM (30 MIN)': '00:30:00',
  'ENZIMA MELASMA': '00:30:00',
  'ENZIMAS PRÓ-CELL': '00:15:00',
  'ENZIMAS PRÓ-FIRM': '00:15:00',
  'GLÚTEO MAX': '00:15:00',
  'HECCUS': '00:30:00',
  'HIDRATAÇÃO': '00:30:00',
  'LAVIEEN': '00:15:00',
  'LAVIEEN CORPORAL': '00:15:00',
  'LIMPEZA DE PELE': '01:00:00',
  'PEELING DE DIAMANTE': '00:30:00',
  'PEELING QUÍMICO': '00:30:00',
  'PREENCHIMENTO': '00:30:00',
  'PRÓ-SHAPE': '01:00:00',
  'PRÓ-BELLA': '00:30:00',
  'PRÓ-FIT': '00:15:00',
  'PRÓ-LIPO': '00:15:00',
  'PRÓ-MESO': '00:30:00',
  'PRÓ-SÉRUM': '00:05:00',
  'PÓS TRATAMENTO': '00:15:00',
  'RADIESSE': '00:30:00',
  'RADIOFREQUÊNCIA': '00:30:00',
  'RETOQUE': '00:15:00',
  'SCULPTRA': '00:30:00',
  'SECAGEM': '00:30:00',
  'ULTRAFORMER BRAÇO': '00:45:00',
  'ULTRAFORMER FULLFACE': '01:00:00',
  'ULTRAFORMER FULLFACE + PESCOÇO': '01:30:00',
  'ULTRAFORMER FULLFACE + PESCOÇO + PAPADA': '01:30:00',
  'ULTRAFORMER GLUTEO': '00:45:00',
  'ULTRAFORMER INTERNO COXA': '01:30:00',
  'ULTRAFORMER MAÇA DO ROSTO': '00:45:00',
  'ULTRAFORMER OLHOS': '00:30:00',
  'ULTRAFORMER PAPADA': '00:30:00',
  'ULTRAFORMER PESCOÇO': '00:40:00',
  'UP BUMBUM': '00:40:00',
  'BUMBUM PERFEITO': '01:30:00',
  'PREENCHIMENTO CORPORAL' : '00:30:00',
  'VICAE' : '00:00:00',
  'VALE PRESENTE' : '00:00:00',
  'LUZ PULSADA' : '00:20:00',
  'HIALURONIDASE' : '00:15:00',
  'BIOIMPEDÂNCIA' : '00:10:00',
  'ULTRAFORMER COLO' : '00:45:00',
  'ULTRAFORMER ABDOME' : '01:00:00',
  'BOTOX PRIME' : '00:30:00',
  }

all_costs_2024 = {
    "BIOIMPEDÂNCIA": {"CUSTO TOTAL": 0.0, "CUSTO PRODUTO": 0.0, "MOD": 0.0, "CUSTO INSUMOS": 0.0},
    "BOTOX LIGHT": {"CUSTO TOTAL": 167.46, "CUSTO PRODUTO": 113.50, "MOD": 45.0, "CUSTO INSUMOS": 3.96},
    "BOTOX POWER": {"CUSTO TOTAL": 307.82, "CUSTO PRODUTO": 227.00, "MOD": 75.0, "CUSTO INSUMOS": 5.82},
    "BUMBUM PERFEITO": {"CUSTO TOTAL": 10234.43, "CUSTO PRODUTO": 8344.80, "MOD": 1750.0, "CUSTO INSUMOS": 139.63},
    "CARBOXITERAPIA": {"CUSTO TOTAL": 24.12, "CUSTO PRODUTO": 8.72, "MOD": 11.65, "CUSTO INSUMOS": 3.75},
    "CO2 CICATRIZ": {"CUSTO TOTAL": 189.24, "CUSTO PRODUTO": 153.9, "MOD": 20.0, "CUSTO INSUMOS": 15.34},
    "CO2 COLO": {"CUSTO TOTAL": 214.24, "CUSTO PRODUTO": 153.9, "MOD": 50.0, "CUSTO INSUMOS": 10.34},
    "CO2 MÃOS": {"CUSTO TOTAL": 189.24, "CUSTO PRODUTO": 153.9, "MOD": 25.0, "CUSTO INSUMOS": 10.34},
    "CO2 OLHEIRAS": {"CUSTO TOTAL": 189.24, "CUSTO PRODUTO": 153.9, "MOD": 25.0, "CUSTO INSUMOS": 10.34},
    "CO2 PESCOÇO": {"CUSTO TOTAL": 214.24, "CUSTO PRODUTO": 153.9, "MOD": 50.0, "CUSTO INSUMOS": 10.34},
    "CO2 ROSTO": {"CUSTO TOTAL": 249.24, "CUSTO PRODUTO": 153.9, "MOD": 85.0, "CUSTO INSUMOS": 10.34},
    "CRIOLIPÓLISE": {"CUSTO TOTAL": 103.17, "CUSTO PRODUTO": 60.0, "MOD": 23.3, "CUSTO INSUMOS": 19.87},
    "DERMAROLLER": {"CUSTO TOTAL": 115.48, "CUSTO PRODUTO": 33.0, "MOD": 80.0, "CUSTO INSUMOS": 2.48},
    "DRENAGEM": {"CUSTO TOTAL": 28.91, "CUSTO PRODUTO": 2.4, "MOD": 23.3, "CUSTO INSUMOS": 3.21},
    "DRENAGEM 30 MIN": {"CUSTO TOTAL": 17.26, "CUSTO PRODUTO": 2.4, "MOD": 11.65, "CUSTO INSUMOS": 3.21},
    "ENZIMA MELASMA": {"CUSTO TOTAL": 56.12, "CUSTO PRODUTO": 32.46, "MOD": 20.0, "CUSTO INSUMOS": 3.66},
    "GLÚTEO MAX": {"CUSTO TOTAL": 98.36, "CUSTO PRODUTO": 73.6, "MOD": 20.0, "CUSTO INSUMOS": 3.08},
    "HECCUS": {"CUSTO TOTAL": 21.6, "CUSTO PRODUTO": 6.87, "MOD": 11.65, "CUSTO INSUMOS": 3.08},
    "HIALURONIDASE": {"CUSTO TOTAL": 44.6, "CUSTO PRODUTO": 44.6, "MOD": 0.0, "CUSTO INSUMOS": 0.0},
    "HIDRATAÇÃO": {"CUSTO TOTAL": 25.09, "CUSTO PRODUTO": 2.79, "MOD": 11.65, "CUSTO INSUMOS": 10.65},
    "LAVIEEN": {"CUSTO TOTAL": 98.12, "CUSTO PRODUTO": 56.25, "MOD": 0.0, "CUSTO INSUMOS": 41.87},
    "LIMPEZA DE PELE": {"CUSTO TOTAL": 34.70, "CUSTO PRODUTO": 9.34, "MOD": 23.30, "CUSTO INSUMOS": 2.06},
    "LUZ PULSADA": {"CUSTO TOTAL": 35.42, "CUSTO PRODUTO": 5.93, "MOD": 23.30, "CUSTO INSUMOS": 6.19},
    "PEELING DE DIAMANTE": {"CUSTO TOTAL": 31.46, "CUSTO PRODUTO": 6.25, "MOD": 23.30, "CUSTO INSUMOS": 1.91},
    "PEELING QUÍMICO": {"CUSTO TOTAL": 31.34, "CUSTO PRODUTO": 9.27, "MOD": 20.0, "CUSTO INSUMOS": 2.06},
    "PREENCHIMENTO": {"CUSTO TOTAL": 298.11, "CUSTO PRODUTO": 218.0, "MOD": 60.0, "CUSTO INSUMOS": 20.11},
    "PREENCHIMENTO CORPORAL": {"CUSTO TOTAL": 423.55, "CUSTO PRODUTO": 323.44, "MOD": 80.0, "CUSTO INSUMOS": 20.11},
    "PREENCHIMENTO CORPORAL 2 ML": {"CUSTO TOTAL": 423.55, "CUSTO PRODUTO": 323.44, "MOD": 80.0, "CUSTO INSUMOS": 20.11},
    "PRÓ-BELLA": {"CUSTO TOTAL": 67.10, "CUSTO PRODUTO": 43.89, "MOD": 20.0, "CUSTO INSUMOS": 3.21},
    "PRÓ-CELL": {"CUSTO TOTAL": 39.55, "CUSTO PRODUTO": 21.14, "MOD": 20.0, "CUSTO INSUMOS": 3.41},
    "PRÓ-FIRM": {"CUSTO TOTAL": 53.17, "CUSTO PRODUTO": 34.76, "MOD": 20.0, "CUSTO INSUMOS": 3.41},
    "PRÓ-FIT": {"CUSTO TOTAL": 55.72, "CUSTO PRODUTO": 37.49, "MOD": 20.0, "CUSTO INSUMOS": 3.23},
    "PRÓ-LIPO": {"CUSTO TOTAL": 46.51, "CUSTO PRODUTO": 23.10, "MOD": 20.0, "CUSTO INSUMOS": 3.41},
    "PRÓ-MESO": {"CUSTO TOTAL": 50.82, "CUSTO PRODUTO": 27.41, "MOD": 20.0, "CUSTO INSUMOS": 3.41},
    "PRÓ-SÉRUM": {"CUSTO TOTAL": 27.50, "CUSTO PRODUTO": 22.50, "MOD": 5.0, "CUSTO INSUMOS": 0.0},
    "PRÓ-SHAPE": {"CUSTO TOTAL": 38.45, "CUSTO PRODUTO": 8.29, "MOD": 23.30, "CUSTO INSUMOS": 6.86},
    "RADIESSE": {"CUSTO TOTAL": 701.49, "CUSTO PRODUTO": 610.0, "MOD": 70.0, "CUSTO INSUMOS": 21.49},
    "RADIOFREQUÊNCIA": {"CUSTO TOTAL": 28.65, "CUSTO PRODUTO": 3.29, "MOD": 23.30, "CUSTO INSUMOS": 2.06},
    "RETOQUE": {"CUSTO TOTAL": 0.0, "CUSTO PRODUTO": 0.0, "MOD": 0.0, "CUSTO INSUMOS": 0.0},
    "SCULPTRA": {"CUSTO TOTAL": 1034.49, "CUSTO PRODUTO": 938.00, "MOD": 75.00, "CUSTO INSUMOS": 21.49},
    "SECAGEM": {"CUSTO TOTAL": 21.59, "CUSTO PRODUTO": 4.48, "MOD": 15.00, "CUSTO INSUMOS": 2.11},
    "ULTRAFORMER ABDOME": {"CUSTO TOTAL": 735.62, "CUSTO PRODUTO": 0.0, "MOD": 40.00, "CUSTO INSUMOS": 695.62},
    "ULTRAFORMER BRAÇO": {"CUSTO TOTAL": 1018.96, "CUSTO PRODUTO": 945.00, "MOD": 60.00, "CUSTO INSUMOS": 13.96},
    "ULTRAFORMER COLO": {"CUSTO TOTAL": 516.46, "CUSTO PRODUTO": 0.0, "MOD": 30.00, "CUSTO INSUMOS": 486.46},
    "ULTRAFORMER FULLFACE": {"CUSTO TOTAL": 736.46, "CUSTO PRODUTO": 682.50, "MOD": 40.00, "CUSTO INSUMOS": 13.96},
    "ULTRAFORMER FULLFACE + PESCOÇO": {"CUSTO TOTAL": 1019.92, "CUSTO PRODUTO": 945.00, "MOD": 60.00, "CUSTO INSUMOS": 14.92},
    "ULTRAFORMER FULLFACE + PESCOÇO + PAPADA": {"CUSTO TOTAL": 1289.92, "CUSTO PRODUTO": 1155.00, "MOD": 120.00, "CUSTO INSUMOS": 14.92},
    "ULTRAFORMER GLUTEO": {"CUSTO TOTAL": 913.96, "CUSTO PRODUTO": 840.00, "MOD": 60.00, "CUSTO INSUMOS": 13.96},
    "ULTRAFORMER INTERNO COXA": {"CUSTO TOTAL": 1343.96, "CUSTO PRODUTO": 1260.00, "MOD": 70.00, "CUSTO INSUMOS": 13.96},
    "ULTRAFORMER MAÇA DO ROSTO": {"CUSTO TOTAL": 421.46, "CUSTO PRODUTO": 367.50, "MOD": 40.00, "CUSTO INSUMOS": 13.96},
    "ULTRAFORMER OLHOS": {"CUSTO TOTAL": 243.96, "CUSTO PRODUTO": 210.00, "MOD": 20.00, "CUSTO INSUMOS": 13.96},
    "ULTRAFORMER PAPADA": {"CUSTO TOTAL": 253.96, "CUSTO PRODUTO": 210.00, "MOD": 30.00, "CUSTO INSUMOS": 13.96},
    "ULTRAFORMER PESCOÇO": {"CUSTO TOTAL": 463.96, "CUSTO PRODUTO": 420.00, "MOD": 30.00, "CUSTO INSUMOS": 13.96},
    "UP BUMBUM": {"CUSTO TOTAL": 5136.73, "CUSTO PRODUTO": 4172.40, "MOD": 875.00, "CUSTO INSUMOS": 89.33},
    "VALE PRESENTE": {"CUSTO TOTAL": 0.0, "CUSTO PRODUTO": 0.0, "MOD": 0.0, "CUSTO INSUMOS": 0.0},
    "VICAE": {"CUSTO TOTAL": 56.60, "CUSTO PRODUTO": 56.60, "MOD": 0.0, "CUSTO INSUMOS": 0.0},
    "BOTOX PRIME" : {"CUSTO TOTAL": 190.00, "CUSTO PRODUTO": 237.5, "MOD": 60.0, "CUSTO INSUMOS": 5.82},
    "'VALE PRESENTE'": {"CUSTO TOTAL": 0.0, "CUSTO PRODUTO": 0.0, "MOD": 0.0, "CUSTO INSUMOS": 0.0}
}

# %% [markdown]
# ## Tratando as Bases:

# %% [markdown]
# ### Vendas

# %%
arquivos = os.listdir("C:/Users/novo1/OneDrive/Desktop/Dev/Rentabilidade Anual/Bases/Venda Mesal Bruta/2025")

lista_arquvios = []

for arquivo in arquivos:
    if arquivo.endswith('.xlsx'):
        df = pd.read_excel(f'C:/Users/novo1/OneDrive/Desktop/Dev/Rentabilidade Anual/Bases/Venda Mesal Bruta/2025/{arquivo}')
        lista_arquvios.append(df)
        print(f"Base {arquivo} Concatenada com Sucesso!")

vmb_2025_concat = pd.concat(lista_arquvios)
vmb_2025_concat.to_csv('C:/Users/novo1/OneDrive/Desktop/Dev/Rentabilidade Anual/Bases/Venda Mesal Bruta/2025/vmb_2025_concat.csv', index=False)
print("Todas as Bases Concatenadas")
# Out:
# Base vmb_2025_01.xlsx Concatenada com Sucesso!
# Base vmb_2025_02.xlsx Concatenada com Sucesso!
# Base vmb_2025_03.xlsx Concatenada com Sucesso!
# Base vmb_2025_04.xlsx Concatenada com Sucesso!
# Base vmb_2025_05.xlsx Concatenada com Sucesso!
# Todas as Bases Concatenadas

# %%
vmb_concat_path = 'C:/Users/novo1/OneDrive/Desktop/Dev/Rentabilidade Anual/Bases/Venda Mesal Bruta/2025/vmb_2025_concat.csv'


vmb_concat = pd.read_csv(vmb_concat_path,low_memory=False)

vmb_concat_columns = ['ID orçamento','ID cliente','Data venda', 'Status','Mês venda',
                       'Unidade','Valor líquido','Procedimento','Quantidade',
                       'Valor tabela item', 'Valor liquido item']



vmb_concat = vmb_concat[vmb_concat_columns]

columns_to_fill_nan = ['Valor liquido item','Valor tabela item','Valor líquido']

vmb_concat[columns_to_fill_nan] = vmb_concat[columns_to_fill_nan].fillna(0)

vmb_concat = vmb_concat.loc[vmb_concat["Status"] == "Finalizado"]

vmb_concat['Unidade'].unique()

#tratando a coluna de datas: 
vmb_concat['Data venda'] = pd.to_datetime(vmb_concat['Data venda'], errors='coerce')
#Criando coluna de Ano:
vmb_concat['Ano de venda'] = vmb_concat['Data venda'].dt.year

# Tirando unidade que não contam e unidades que fecharam

branchs_to_remove = ['RIBEIRÃO PRETO','BELO HORIZONTE',
                     'INSIDE SALES', 'nan', 'Matriz BKO',
                     'PRAIA GRANDE', 'LOJA ONLINE']

vmb_concat = vmb_concat.loc[~vmb_concat['Unidade'].isin(branchs_to_remove)]

# Valores menor que 1 como zero
vmb_concat.loc[vmb_concat['Valor liquido item'] <= 1, 'Valor liquido item'] = 0

# Trocando Mês nan por março (verificado)
vmb_concat.loc[vmb_concat['Mês venda'].isna(), 'Mês venda'] = "Março"

# Procedimentos Nan como Vale Presente: 
vmb_concat.loc[vmb_concat['Procedimento'].isna(),'Procedimento'] = "Vale Presente"

# Unidades Nan como "Sorocaba" (validado)
vmb_concat.loc[vmb_concat['Unidade'].isna(),'Unidade'] = "SOROCABA"

# Quantidade como Nan como 1 (validado): 
vmb_concat.loc[vmb_concat['Quantidade'].isna(),'Quantidade'] = 1

# Quantidade "Finalizado" para 1
vmb_concat.loc[vmb_concat['Quantidade'] == "Finalizado", 'Quantidade'] = 1

#tratando Procedimentos
vmb_concat["Procedimento_padronizado"] = vmb_concat['Procedimento'].map(Sales_dic)

#Quantidade de Vale Presente para 1: 
vmb_concat.loc[vmb_concat['Procedimento_padronizado'] == "VALE PRESENTE",'Quantidade'] = 1

# Tirando depilação: 
vmb_concat = vmb_concat.loc[vmb_concat['Procedimento_padronizado'] != "DEPILACAO"]

# Colunas de custo: 
vmb_concat['Custo Produto'] = vmb_concat['Procedimento_padronizado'].map(lambda x: all_costs_2024.get(x, {}).get('CUSTO PRODUTO', 0))
vmb_concat['Custo Insumos'] = vmb_concat['Procedimento_padronizado'].map(lambda x: all_costs_2024.get(x, {}).get('CUSTO INSUMOS', 0))
vmb_concat['Custo Mod'] = vmb_concat['Procedimento_padronizado'].map(lambda x: all_costs_2024.get(x, {}).get('MOD', 0))

vmb_concat['Custo Direto'] = vmb_concat['Custo Produto'] + vmb_concat['Custo Insumos'] + vmb_concat['Custo Mod']

vmb_concat["Quantidade"] = vmb_concat["Quantidade"].replace(".",",")

vmb_concat['Quantidade'] = pd.to_numeric(vmb_concat['Quantidade'],errors='coerce')

vmb_concat['Quantidade'] = vmb_concat['Quantidade'].astype(int)

vmb_concat['Custo Direto Total'] = vmb_concat['Custo Direto'] * vmb_concat['Quantidade']

vmb_concat['Valor unitário'] = vmb_concat['Valor liquido item'] / vmb_concat['Quantidade']

vmb_concat["Valor tabela total"] = vmb_concat['Valor tabela item'] * vmb_concat['Quantidade']

#dropndo colunad não utilizadas mais
vmb_concat = vmb_concat.drop(columns=['Custo Direto'])

vmb_concat["Cortesia?"] = (vmb_concat['Procedimento'].str.contains("CORTESIA", case=False) | (vmb_concat['Valor liquido item'] == 0))

# Trazendo os Custos de Vendas para o DF:
cartao = 0.0818
imposto = 0.1425
comissao = 0.04

cmv = cartao + imposto + comissao

vmb_concat['Custo Sobre Venda'] = vmb_concat['Valor liquido item'] * cmv

# Colocando Tempo dos procedimentos
vmb_concat["Tempo Procedimento"] = vmb_concat['Procedimento_padronizado'].map(duration_dic)

#tratando o tempo
vmb_concat['Tempo Procedimento'] = pd.to_timedelta(vmb_concat['Tempo Procedimento']).dt.total_seconds() // 60

vmb_concat['Tempo Total'] = vmb_concat['Tempo Procedimento'] * vmb_concat["Quantidade"]

vmb_concat_columns = ['ID orçamento', 'ID cliente', 'Status', 'Mês venda', 'Unidade',
                      'Valor líquido','Procedimento_padronizado', 'Quantidade',
                      'Valor tabela item','Valor tabela total','Valor liquido item','Valor unitário','Tempo Total', 'Custo Produto',
                      'Custo Insumos', 'Custo Mod', 'Custo Direto Total', 'Custo Sobre Venda','Cortesia?']



vmb_concat = vmb_concat[vmb_concat_columns]

vmb_concat = vmb_concat.rename(columns={"Tempo Total" : "Tempo Utilizado"})

# Horas utilizadas por unidade: 

df_tempo_pago = vmb_concat.groupby(['Unidade','Mês venda']).agg({"Tempo Utilizado" : 'sum'}).reset_index()

#vmb_concat.to_csv("C:/Users/novo1/OneDrive/Desktop/Dev/Rentabilidade Anual/Bases/Venda Mesal Bruta/2024/vmb_2024_concat_treated.csv")

df_tempo_pago
# Out:
#          Unidade  Mês venda  Tempo Utilizado
# 0     ALPHAVILLE      Abril          21460.0
# 1     ALPHAVILLE  Fevereiro          15820.0
# 2     ALPHAVILLE    Janeiro          14510.0
# 3     ALPHAVILLE       Maio          17700.0
# 4     ALPHAVILLE      Março           9570.0
# ..           ...        ...              ...
# 95  VILA MASCOTE      Abril          16420.0
# 96  VILA MASCOTE  Fevereiro           6445.0
# 97  VILA MASCOTE    Janeiro           9795.0
# 98  VILA MASCOTE       Maio          13965.0
# 99  VILA MASCOTE      Março           8750.0
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Base Custo Fixo:

# %%
custo_fixo = pd.read_excel("C:/Users/novo1/OneDrive/Desktop/Dev/Rentabilidade Anual/Bases/Custos Fixos/2025/CF-txSala_Mensal.xlsx")

custo_fixo

taxas = pd.read_excel("C:/Users/novo1/OneDrive/Desktop/Dev/Rentabilidade Anual/Bases/Custos Fixos/2025/CF-txSala_Mensal.xlsx",sheet_name="IMP + CART")

taxas
# Out:
#          Mês  Taxa_cartão  Impostos  Comissao  Custo_Sobre_Venda
# 0    Janeiro        0.083    0.0760      0.04             0.1990
# 1  Fevereiro        0.077    0.0780      0.04             0.1950
# 2      Março        0.079    0.0820      0.04             0.2010
# 3      Abril        0.066    0.0606      0.04             0.1666
# 4       Maio        0.079    0.0640      0.04             0.1830

# %%
#Merge da base CF com DF de tempo Utilizado

df_merged_cf = pd.merge(df_tempo_pago,custo_fixo,how='left',
    left_on=['Unidade', 'Mês venda'],
    right_on=['Unidade', 'Mês'])

df_merged_cf["Valor Tempo Utilizado"] = df_merged_cf['Tempo Utilizado'] * df_merged_cf['Taxa Sala (Min)']

df_merged_cf['Tempo Ocioso'] = df_merged_cf['Minutos Disponivel'] - df_merged_cf['Tempo Utilizado']

df_merged_cf["Valor Tempo Ocioso"] = df_merged_cf['Tempo Ocioso'] * df_merged_cf['Taxa Sala (Min)']

df_merged_cf_columns = ['Unidade', 'Custo Fixo + Bko','Dias uteis', 'Hora/Dia','Mês',
                        'Salas','Minutos Disponivel', 'Taxa Sala (Hr)', 'Taxa Sala (Min)',
                        'Tempo Utilizado','Valor Tempo Utilizado', 'Tempo Ocioso','Valor Tempo Ocioso']

df_merged_cf = df_merged_cf[df_merged_cf_columns]

df_merged_cf["Taxa Ociosidade (Min)"] = df_merged_cf["Valor Tempo Ocioso"] / df_merged_cf['Tempo Utilizado']

df_merged_cf

df_taxa_sala_ociosidade = df_merged_cf.groupby(['Unidade', 'Mês']).agg({
    'Taxa Sala (Min)': 'first',
    'Taxa Ociosidade (Min)': 'first'
}).reset_index()

df_taxa_sala_ociosidade
# Out:
#          Unidade        Mês  Taxa Sala (Min)  Taxa Ociosidade (Min)
# 0     ALPHAVILLE      Abril         0.845043               2.037396
# 1     ALPHAVILLE  Fevereiro         0.800533               2.903577
# 2     ALPHAVILLE    Janeiro         0.857719               3.469299
# 3     ALPHAVILLE       Maio         1.071902               3.361049
# 4     ALPHAVILLE      Março         0.765686               5.090971
# ..           ...        ...              ...                    ...
# 95  VILA MASCOTE      Abril         0.960918               3.322832
# 96  VILA MASCOTE  Fevereiro         0.735269               7.615652
# 97  VILA MASCOTE    Janeiro         0.831044               5.379516
# 98  VILA MASCOTE       Maio         0.956087               4.055413
# 99  VILA MASCOTE      Março         0.869863               6.407161
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Merge da Base de Vednas com Taxas:

# %%
df_final = pd.merge(
    vmb_concat,
    df_taxa_sala_ociosidade,
    how='left',
    left_on=['Unidade', 'Mês venda'],
    right_on=['Unidade', 'Mês']
)

df_final["Custo Fixo"] = ((df_final['Tempo Utilizado']* df_final['Taxa Sala (Min)']) + (df_final['Tempo Utilizado']* df_final['Taxa Ociosidade (Min)']))

receita_gerada = df_final['Valor liquido item'].sum()

df_final['Custo Total'] = df_final['Custo Fixo'] + df_final['Custo Direto Total'] + df_final['Custo Sobre Venda']

df_final['Lucro'] = df_final['Valor liquido item'] - df_final['Custo Total']

df_final['Mês venda'].unique()

df_final.drop(columns='Mês',inplace=True)

B = df_final.loc[df_final['Unidade'] == "JARDINS"]

B
# Out:
#        ID orçamento  ID cliente      Status Mês venda  Unidade  Valor líquido  \
# 1            412497    562644.0  Finalizado   Janeiro  JARDINS            0.0
# 7            422898   1006872.0  Finalizado   Janeiro  JARDINS          246.0
# 8            422898   1006872.0  Finalizado   Janeiro  JARDINS            0.0
# 9            423146    781081.0  Finalizado   Janeiro  JARDINS         1700.0
# 33           423796   1007287.0  Finalizado   Janeiro  JARDINS          900.0
# ...             ...         ...         ...       ...      ...            ...
# 27424        455491    466412.0  Finalizado      Maio  JARDINS            0.0
# 27425        455491    466412.0  Finalizado      Maio  JARDINS            0.0
# 27431        455498   1040367.0  Finalizado      Maio  JARDINS          349.0
# 27432        455498   1040367.0  Finalizado      Maio  JARDINS            0.0
# 27433        455498   1040367.0  Finalizado      Maio  JARDINS            0.0
#
# ...

# %% [markdown]
# ### Appointments

# %%
arquivos = os.listdir("C:/Users/novo1/OneDrive/Desktop/Dev/Rentabilidade Anual/Bases/Agendamento/2024")

lista_arquvios = []

for arquivo in arquivos:
    if arquivo.endswith('.xlsx'):
        df = pd.read_excel(f'C:/Users/novo1/OneDrive/Desktop/Dev/Rentabilidade Anual/Bases/Agendamento/2024/{arquivo}')
        lista_arquvios.append(df)
        print(f"Base {arquivo} Concatenada com Sucesso!")
    


appointments_2024_concat = pd.concat(lista_arquvios)
appointments_2024_concat.to_csv('C:/Users/novo1/OneDrive/Desktop/Dev/Rentabilidade Anual/Bases/Agendamento/2024/appointments_2024_concat.csv', index=False)
print("Todas as Bases Concatenadas")
# Out:
# Base agd_2024_01.xlsx Concatenada com Sucesso!
# Base agd_2024_02.xlsx Concatenada com Sucesso!
# Base agd_2024_03.xlsx Concatenada com Sucesso!
# Base agd_2024_04.xlsx Concatenada com Sucesso!
# Base agd_2024_05.xlsx Concatenada com Sucesso!
# Base agd_2024_06.xlsx Concatenada com Sucesso!
# Base agd_2024_07.xlsx Concatenada com Sucesso!
# Base agd_2024_08.xlsx Concatenada com Sucesso!
# Base agd_2024_09.xlsx Concatenada com Sucesso!
# Base agd_2024_10.xlsx Concatenada com Sucesso!
# Base agd_2024_11.xlsx Concatenada com Sucesso!
# Base agd_2024_12.xlsx Concatenada com Sucesso!
# Todas as Bases Concatenadas
